# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow scikit-learn
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.17.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)

# %%
# !unzip "/content/drive/My Drive/DataSet.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00312_png.rf.0f026f535efd3c25c4c3bd985f169bdd.jpg
#   inflating: /content/DataSet/valid/images/00014_00009_00012_png.rf.02ffbac072397fe4f36979ba80f74fb9.jpg
#   inflating: /content/DataSet/valid/images/000297_jpg.rf.b373c5e86c5e0fcfe7a99082beeba1d2.jpg
#   inflating: /content/DataSet/valid/images/000352_jpg.rf.d63e34658183df08ad20ef345a34795f.jpg
#   inflating: /content/DataSet/valid/images/000387_jpg.rf.7119e3f9c6a97ec54b1de9f62fd6f7b2.jpg
#   inflating: /content/DataSet/valid/images/000242_jpg.rf.ce0b1a3828ba64c185b3638cd90951c6.jpg
#   inflating: /content/DataSet/valid/images/000354_jpg.rf.b7ccfe0e9fd239ec28a6518202c7c531.jpg
#   inflating: /content/DataSet/valid/images/000319_jpg.rf.1fd32a8ec85d8ece29bdcc792fdf960c.jpg
#   inflating: /content/DataSet/valid/images/000330_jpg.rf.e8b0af092d57c4f34925bb7177a0b474.jpg
#   inflating: /content/DataSet/valid/images/00014_00010_00006_png.rf.fc6789dfb26ab8b258a45781c138f7d8.jpg
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00314_png.rf.396f655b57ad5a4d7b4c5b7913082e91.jpg
#   inflating: /content/DataSet/valid/images/000165_jpg.rf.e9dabfaaf12417e2ba0ac7ec3127c251.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00006_png.rf.e6ce907e9d1c78a8eea7b39d096b66cc.jpg
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00281_png.rf.cc41a23c0bb5dbad1a314ad1d4a147a5.jpg
#   inflating: /content/DataSet/valid/images/000164_jpg.rf.4299a2cf7fe633528bda8e6c82bba7e0.jpg
#   inflating: /content/DataSet/valid/images/000161_jpg.rf.ae64f76d8ef6076b247838f85e05de8f.jpg
#   inflating: /content/DataSet/valid/images/000154_jpg.rf.10e8182b19d397c1a3fc5496f48956c6.jpg
#   inflating: /content/DataSet/valid/images/00014_00010_00000_png.rf.a400f3cc1c01ae5b1e410948f7919e92.jpg
#   inflating: /content/DataSet/valid/images/000197_jpg.rf.c3fc560c02bac1c6baeec423405f5c24.jpg
#   inflating: /content/DataSet/valid/images/000187_jpg.rf.a4e0eb7a38e4d4cadcef43e381a0f033.jpg
#   inflating: /content/DataSet/valid/images/00014_00018_00009_png.rf.2d72ed302f587a671e54afaf1a09a0a9.jpg
#   inflating: /content/DataSet/valid/images/00014_00012_00029_png.rf.366e398c9dd622533fd1892f9d836749.jpg
#   inflating: /content/DataSet/valid/images/00014_00007_00018_png.rf.b1a6bc22dfa2520a4f80c645087c38d9.jpg
#   inflating: /content/DataSet/valid/images/00014_00022_00001_png.rf.5f053622d21d091f24ead75941f99403.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00026_png.rf.038e8ad38151a8f6155603801aa4e2bd.jpg
#   inflating: /content/DataSet/valid/images/000264_jpg.rf.6876ea6d3378e9d03db30c2183cc5045.jpg
#   inflating: /content/DataSet/valid/images/000176_jpg.rf.96cf6ceea532f7e4169a4cea717a6219.jpg
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00279_png.rf.2e0a92fd2dfb1632abbebc718f958d2e.jpg
#   inflating: /content/DataSet/valid/images/00014_00013_00010_png.rf.0358de740627248f20390ba5887f0ae0.jpg
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00277_png.rf.28c9318804d24b05043bdbc290728c81.jpg
#   inflating: /content/DataSet/valid/images/00014_00023_00014_png.rf.4f936a83f573af4da01d2c99bd65257c.jpg
#   inflating: /content/DataSet/train/images/FisheyeCamera_1_00318_png.rf.031d65ad68677a577ed39965b996ff9a.jpg
#   inflating: /content/DataSet/valid/images/00014_00009_00002_png.rf.f35bed5e27fca545a320efeb4b5d81d0.jpg
#   inflating: /content/DataSet/valid/images/000158_jpg.rf.de2717752337de37af3909a837ac1ecd.jpg
#   inflating: /content/DataSet/valid/images/000159_jpg.rf.1453deeb1721dd612b3e4c6ec33da5d8.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00015_png.rf.7deb3d52b8955c9f16bc4630ca2b3a09.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00010_png.rf.eaf26fb45c806ade178b403b585eeb40.jpg
#   inflating: /content/DataSet/valid/images/00014_00009_00004_png.rf.73407ef1038d43d87b332be788574a66.jpg
#   inflating: /content/DataSet/valid/images/00014_00009_00021_png.rf.86ee460f79a2e8a2d702df174c862850.jpg
#   inflating: /content/DataSet/valid/images/000299_jpg.rf.37004e619318422c6e11e4db672b5a37.jpg
#   inflating: /content/DataSet/valid/images/00014_00011_00013_png.rf.5c38fd5ec4ddf261665eb299b209c6cd.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00012_png.rf.277d9f2527db84cf64fed938bfe0eb22.jpg
#   inflating: /content/DataSet/train/images/001284_jpg.rf.c0b43ff0bafc6d5baa550817903961e4.jpg
#   inflating: /content/DataSet/train/images/001217_jpg.rf.d0b37eb8a1d587228bf0b51642e31621.jpg
#   inflating: /content/DataSet/train/images/001234_jpg.rf.dfa041ce015e745b039611a3e691990a.jpg
#   inflating: /content/DataSet/train/images/001237_jpg.rf.366f62d603001ed161d2403061a5ed7c.jpg
#   inflating: /content/DataSet/train/images/001244_jpg.rf.d40f75f10ded61e6b60fbc25b6063811.jpg
#   inflating: /content/DataSet/train/images/001209_jpg.rf.a3104aa8e563d4e96201783f6917ce0f.jpg
#   inflating: /content/DataSet/train/images/001441_jpg.rf.b92c6a4b7b095f2fd07633f52f1c0677.jpg
#   inflating: /content/DataSet/valid/images/00014_00009_00005_png.rf.e3aaedc6dac0cc23af08380064bf51f1.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00025_png.rf.9f597254f67382352eda6f7bf0ccfe90.jpg
#   inflating: /content/DataSet/train/images/001238_jpg.rf.dc54b70f9a2df8548030f2b11a742543.jpg
#   inflating: /content/DataSet/train/images/001270_jpg.rf.89a939adde56915011f1e660be19d1d9.jpg
#   inflating: /content/DataSet/train/images/001232_jpg.rf.fa050b6afd8bebd0558a948a8d9c638f.jpg
#   inflating: /content/DataSet/train/images/001420_jpg.rf.b940ab21f8347b653a31f9152598772a.jpg
#   inflating: /content/DataSet/train/images/001260_jpg.rf.dc77349fe44cb53a610dbe7c1b2fbf9d.jpg
#   inflating: /content/DataSet/train/images/001265_jpg.rf.914bba9063f3a8d2febc459d73ab54e4.jpg
#   inflating: /content/DataSet/train/images/001215_jpg.rf.9a04f91268a90ff78fca5241a90a7513.jpg
#   inflating: /content/DataSet/train/images/001240_jpg.rf.a3cbf51bb9e964e80f9426f69abbec28.jpg
#   inflating: /content/DataSet/train/images/001283_jpg.rf.ddae58eac72d77eed25da90d8134ce43.jpg
#   inflating: /content/DataSet/train/images/001243_jpg.rf.71b9323935e7c99eb556e65b1f217c72.jpg
#   inflating: /content/DataSet/train/images/001411_jpg.rf.79f8315de14805a134f9a88de4233fa7.jpg
#   inflating: /content/DataSet/train/images/001239_jpg.rf.26b4ca5e1f95a67cfe87a10160625899.jpg
#   inflating: /content/DataSet/train/images/001233_jpg.rf.e9b917837ee480cde6d5f304141ba4ff.jpg
#   inflating: /content/DataSet/train/images/001241_jpg.rf.7f9cd5cc657adbfe08bec451271b043e.jpg
#   inflating: /content/DataSet/train/images/001222_jpg.rf.d616bae27fe70c4482c87c3d8f33f0bd.jpg
#   inflating: /content/DataSet/train/images/001208_jpg.rf.a7cf867d08bd18fb044d70c92291a4de.jpg
#   inflating: /content/DataSet/train/images/001210_jpg.rf.1b3c099f8e9f7325c89b65522d201405.jpg
#   inflating: /content/DataSet/train/images/001231_jpg.rf.196eb62d02215471cbd3c8c37d38b256.jpg
#   inflating: /content/DataSet/train/images/001403_jpg.rf.6fbe81e02243fc82f063b62bff1abb70.jpg
#   inflating: /content/DataSet/train/images/001251_jpg.rf.ff02c4f3ac955d5a0464089bb7e18a12.jpg
#   inflating: /content/DataSet/train/images/001218_jpg.rf.c2b2a77e9cfb5022d35a9c256ebc0c3a.jpg
#   inflating: /content/DataSet/train/images/001212_jpg.rf.fcd6fab2b8d8d4584df6fd94d64b443b.jpg
#   inflating: /content/DataSet/train/images/001235_jpg.rf.d7866ae7cbb32183e9ac52f0b3d330be.jpg
#   inflating: /content/DataSet/train/images/001220_jpg.rf.1241a54907ffc3c87dad7b77532a9d61.jpg
#   inflating: /content/DataSet/train/images/001204_jpg.rf.0a152ef86fae0f1d91b9531fcea59bb3.jpg
#   inflating: /content/DataSet/train/images/001269_jpg.rf.9c69df703aa0e6924b450229f5f7bd5e.jpg
#   inflating: /content/DataSet/train/images/001216_jpg.rf.a64c0664e70498fae2983b203e53fdfd.jpg
#   inflating: /content/DataSet/train/images/001088_jpg.rf.7dec06fdc60a10a6159dd6261672f24f.jpg
#   inflating: /content/DataSet/valid/images/000208_jpg.rf.832e26c0ed8a8bd11d3f9a9e3a49c98a.jpg
#   inflating: /content/DataSet/train/images/001257_jpg.rf.af5ce9134e4d93e378a601ef925834ac.jpg
#   inflating: /content/DataSet/train/images/001225_jpg.rf.c9a7675428d182a9cc6dbca3b3b77b24.jpg
#   inflating: /content/DataSet/train/images/001227_jpg.rf.b6deb4bf073ea67d99d868e6e857226f.jpg
#   inflating: /content/DataSet/train/images/001264_jpg.rf.a47144d82bcd3e1e2ea46aee9d02b163.jpg
#   inflating: /content/DataSet/train/images/001221_jpg.rf.52805527a0b73efb626972229d08b8ae.jpg
#   inflating: /content/DataSet/train/images/001258_jpg.rf.f4bb4f043144f75d8f94582a8ad9f018.jpg
#   inflating: /content/DataSet/train/images/001213_jpg.rf.3a9a2bc9c57719a166cfdc9b67aef66d.jpg
#   inflating: /content/DataSet/train/images/001226_jpg.rf.93a76f0d2b6622e5881aeabe323c3f06.jpg
#   inflating: /content/DataSet/train/images/001224_JPG_jpg.rf.aef37483dacf41d4edd175dc2ce2cf62.jpg
#   inflating: /content/DataSet/train/images/001096_jpg.rf.c66b9e1f9365045ba64914a2e4e8d4a7.jpg
#   inflating: /content/DataSet/train/images/001081_jpg.rf.b8fe806214351154440d2e87f3f7910f.jpg
#   inflating: /content/DataSet/train/images/001245_jpg.rf.fa3f52594af5ef2b4edeaa51b293179a.jpg
#   inflating: /content/DataSet/train/images/001075_jpg.rf.a050f85a23eaa900d739ecc469e1a693.jpg
#   inflating: /content/DataSet/train/images/001073_jpg.rf.b5eb5f006445f2c4f659331a690f007f.jpg
#   inflating: /content/DataSet/train/images/001200_png_jpg.rf.e766b74d210b515c9348f709d4dc5c75.jpg
#   inflating: /content/DataSet/train/images/001066_jpg.rf.f54b81e49435d7baaba7fd00d5246f74.jpg
#   inflating: /content/DataSet/train/images/001087_jpg.rf.6ee32a4fb836bc5bcd49f718785b4785.jpg
#   inflating: /content/DataSet/train/images/001219_jpg.rf.92ceae699023d13e41cc361ed8bf27b1.jpg
#   inflating: /content/DataSet/train/images/001206_jpg.rf.8a5c5cff39957ab4aa0328ac121a8053.jpg
#   inflating: /content/DataSet/train/images/001202_jpg.rf.b76c39a82ccabb3675961e215f6d6d5f.jpg
#   inflating: /content/DataSet/train/images/001069_jpg.rf.57e243fb810c7ae7a03e1b816b1f5a2a.jpg
#   inflating: /content/DataSet/train/images/001074_jpg.rf.eafd7c67a28ad690d5c53320e85b227e.jpg
#   inflating: /content/DataSet/train/images/001061_jpg.rf.209bfe916de5ac8e2c0590b10c7a5625.jpg
#   inflating: /content/DataSet/train/images/001201_jpg.rf.33e656d501fb8214961f21d2c7e477bd.jpg
#   inflating: /content/DataSet/valid/images/00014_00008_00023_png.rf.7f736e938225b82a2984aa0f3e8de55c.jpg
#   inflating: /content/DataSet/train/images/001069_jpg.rf.81aa218991fedd3a0c0c3bba9c636c57.jpg
#   inflating: /content/DataSet/train/images/001086_jpg.rf.1e669791cf26802adf4503f391c9be10.jpg
#   inflating: /content/DataSet/train/images/001090_jpg.rf.3a1fc91ae0f707a4b4fb2a2577a4def8.jpg
#   inflating: /content/DataSet/train/images/001092_jpg.rf.b18f0bbb0e5e8dda41414e1c27eeba87.jpg
#   inflating: /content/DataSet/train/images/001249_jpg.rf.c78d0118a6225e02f489bd00d3335d92.jpg
#   inflating: /content/DataSet/train/images/001065_jpg.rf.07c50b5f8a4d2c6117b6f2df2e1930e1.jpg
#   inflating: /content/DataSet/train/images/001077_jpg.rf.5a3a8c822505c851c64301fa0aaf0cc5.jpg
#   inflating: /content/DataSet/train/images/001095_jpg.rf.c209e07a77ba7f1df72e706b9f0d3ecf.jpg
#   inflating: /content/DataSet/train/images/001072_jpg.rf.c1c5e4170993104d33414d9116ba752d.jpg
#   inflating: /content/DataSet/train/images/001074_jpg.rf.a9bd1789ba3d29809737348b51e20dd3.jpg
#   inflating: /content/DataSet/train/images/001091_jpg.rf.42004d0a684b0043c1c3cc3a9f23f1e3.jpg
#   inflating: /content/DataSet/train/images/001242_jpg.rf.5581e4a7cff1b2cd504ed7ee643a9057.jpg
#   inflating: /content/DataSet/train/images/001083_jpg.rf.cc4245c01c41ab65bd06c758d1fa47ce.jpg
#   inflating: /content/DataSet/train/images/001058_jpg.rf.da86005ca4f586867394a0c9e9055b86.jpg
#   inflating: /content/DataSet/train/images/001099_jpg.rf.02cfbe77e5f5be8fe91ef77624f90185.jpg
#   inflating: /content/DataSet/train/images/001077_jpg.rf.84111828387808be87e5c9f6f07d1cde.jpg
#   inflating: /content/DataSet/train/images/001084_jpg.rf.6a45e20be9162f0ff5e84c37320d70c4.jpg
#   inflating: /content/DataSet/train/images/001070_jpg.rf.a06b3fc6d19bb81e034c25cab6255f3d.jpg
#   inflating: /content/DataSet/train/images/001093_jpg.rf.43d600731fef76100781db044b59c6fc.jpg
#   inflating: /content/DataSet/train/images/001033_jpg.rf.4c7fcb6cf339f03b34a0db55ff3d94c8.jpg
#   inflating: /content/DataSet/train/images/001094_jpg.rf.f48da21c5bfeb044cdf55a90ebb87ee5.jpg
#   inflating: /content/DataSet/valid/images/00014_00013_00005_png.rf.7afaaa7763228bd8062f208657493059.jpg
#   inflating: /content/DataSet/train/images/001056_jpg.rf.78383d27fbdb59d470c7fbae2ad2699d.jpg
#   inflating: /content/DataSet/train/images/001203_jpg.rf.1a87bb53f038e3c64f27b0906419284c.jpg
#   inflating: /content/DataSet/train/images/001046_jpg.rf.4c614b96ed63f3d96f2017c2959d343c.jpg
#   inflating: /content/DataSet/train/images/001078_jpg.rf.9102fe46c670c9000ca44eaf5050f939.jpg
#   inflating: /content/DataSet/train/images/001008_png_jpg.rf.2ad63462ead8bd3b108fdbff6548c73c.jpg
#   inflating: /content/DataSet/train/images/001039_jpg.rf.eb114f58106b40047f7cc4a8399722e7.jpg
#   inflating: /content/DataSet/train/images/001065_jpg.rf.9c8cefc71672ef271604c833c704433f.jpg
#   inflating: /content/DataSet/train/images/001062_jpg.rf.577a1ed9865c7431d04f1174e8297bba.jpg
#   inflating: /content/DataSet/train/images/001030_jpg.rf.80a4b438942f081d4b748d9e6e9f3b03.jpg
#   inflating: /content/DataSet/train/images/001063_jpg.rf.25288a23345de47c10f003388956cdd2.jpg
#   inflating: /content/DataSet/train/images/001072_jpg.rf.44758fd9ea903be675ecd66132c929fe.jpg
#   inflating: /content/DataSet/train/images/001047_jpg.rf.7fba90c927ec285ecc87a7eacc065f3a.jpg
#   inflating: /content/DataSet/train/images/001032_jpg.rf.a00d4d778e9c7f3c2a191bfe3fbf80ca.jpg
#   inflating: /content/DataSet/train/images/001049_jpg.rf.f6ced132f86d654345f11753ba22192e.jpg
#   inflating: /content/DataSet/train/images/001036_jpg.rf.ca42fc70291b1202ec2a8b2c4ee883ad.jpg
#   inflating: /content/DataSet/train/images/001076_jpg.rf.4d1ae552c3f395245c1c9903159e6c9b.jpg
#   inflating: /content/DataSet/train/images/001047_jpg.rf.0c13a2d7349befde599634bb8510f327.jpg
#   inflating: /content/DataSet/train/images/001044_jpg.rf.547f567b33d671e4b23ae6f57fce2ba4.jpg
#   inflating: /content/DataSet/train/images/001045_jpg.rf.0199c26e1464c6f840cc979eb91d4561.jpg
#   inflating: /content/DataSet/train/images/001054_jpg.rf.3476e14f01897dae40344efc8623bc49.jpg
#   inflating: /content/DataSet/train/images/001044_jpg.rf.f0e31ffc850fccb12d7ef686cc0b025b.jpg
#   inflating: /content/DataSet/train/images/001040_jpg.rf.953845d7348aeeab9e58f525afb92370.jpg
#   inflating: /content/DataSet/train/images/001051_jpg.rf.86d777cffe5baf6dc81e311f16cad4fe.jpg
#   inflating: /content/DataSet/train/images/001020_jpg.rf.aa8b4769d41f5392b2fb28681be84cb8.jpg
#   inflating: /content/DataSet/train/images/001071_jpg.rf.8537213520ca6d601b1ce7562801bf53.jpg
#   inflating: /content/DataSet/train/images/001050_jpg.rf.e1411990bca906b21fcd736c56eaf840.jpg
#   inflating: /content/DataSet/train/images/001018_jpg.rf.04e873920bebff1de7f6278f2da807d4.jpg
#   inflating: /content/DataSet/train/images/001009_jpg.rf.7fc98117d088f45197b8195b0a056b2b.jpg
#   inflating: /content/DataSet/train/images/001010_jpg.rf.193c81e1f19fa9b96a0c836dad825f59.jpg
#   inflating: /content/DataSet/train/images/001007_jpg.rf.122d0e256fba4518d4a724ed0a0aa560.jpg
#   inflating: /content/DataSet/train/images/001025_png_jpg.rf.26e6f9df12a96a792c1de11125a6022a.jpg
#   inflating: /content/DataSet/train/images/001013_jpg.rf.cbc241c6ae32a3a9d0af6a15c1e024f4.jpg
#   inflating: /content/DataSet/train/images/001041_jpg.rf.de3910ff77489417b29e731cab0f1d75.jpg
#   inflating: /content/DataSet/train/images/001016_jpg.rf.ff1bbbaa154a829401510abf7d91785e.jpg
#   inflating: /content/DataSet/train/images/001055_jpg.rf.5281c5d3febb3ed302a2573a3208f472.jpg
#   inflating: /content/DataSet/train/images/001045_jpg.rf.8cb71c7ac87a8c32410e7a2aa6c63379.jpg
#   inflating: /content/DataSet/train/images/001015_jpg.rf.a9bfc11cabca85914adb43b814a3d06c.jpg
#   inflating: /content/DataSet/train/images/001026_jpg.rf.ddec9f4973fadc7cce38f70c767b2add.jpg
#   inflating: /content/DataSet/train/images/000965_jpg.rf.855b455a72c84a642f577d5767c4f6ee.jpg
#   inflating: /content/DataSet/train/images/001053_jpg.rf.7a9ab24dc19ff77dd03e295150fc4e8c.jpg
#   inflating: /content/DataSet/train/images/001017_jpg.rf.d8b58b9177249ba4ecf958aa0226c4ea.jpg
#   inflating: /content/DataSet/train/images/001048_jpg.rf.48108e84eecb90b2af595bc924daab08.jpg
#   inflating: /content/DataSet/train/images/001029_jpg.rf.bc1dc4714dab038975d926b54e492b51.jpg
#   inflating: /content/DataSet/train/images/001034_jpg.rf.61f96f194f2d35fbeb5434f35c98876f.jpg
#   inflating: /content/DataSet/train/images/001068_jpg.rf.33c0a9f2d35e1090a38915e0bd99011b.jpg
#   inflating: /content/DataSet/train/images/000976_JPG_jpg.rf.37419605b09579afc0ad60a72f692a26.jpg
#   inflating: /content/DataSet/train/images/001011_jpg.rf.fe1bc895b0e292fcf81aacec813ba2ad.jpg
#   inflating: /content/DataSet/train/images/000972_JPG_jpg.rf.2eda66d7c38383d2a98a3f8ec3c67b50.jpg
#   inflating: /content/DataSet/train/images/000997_JPG_jpg.rf.f79cb5337aa12a1f58e06010b6b30c30.jpg
#   inflating: /content/DataSet/train/images/001042_jpg.rf.545beff2bbe5abec5feb037ea45529f6.jpg
#   inflating: /content/DataSet/train/images/001019_jpg.rf.5e1e4cd91c5b7744a83ca3d7f77b9933.jpg
#   inflating: /content/DataSet/train/images/000970_JPG_jpg.rf.b3817108c24c43bf5cb0a4e523a1281a.jpg
#   inflating: /content/DataSet/train/images/001043_jpg.rf.d547f1e87077e5b2a3b72ef69c9e9873.jpg
#   inflating: /content/DataSet/train/images/000988_JPG_jpg.rf.0e3b8848dd20ddd90da7706545e12357.jpg
#   inflating: /content/DataSet/train/images/000973_JPG_jpg.rf.6346b15da59f7d44800b32c92e5699f7.jpg
#   inflating: /content/DataSet/train/images/000986_JPG_jpg.rf.1b8f8f88d461250bb1bedc03bd7414f1.jpg
#   inflating: /content/DataSet/train/images/001038_jpg.rf.ff7273eca87fac37cc96a04e492dfa2c.jpg
#   inflating: /content/DataSet/train/images/000999_jpg.rf.0f19bd03254eb7bf28f7a8c4d86489bb.jpg
#   inflating: /content/DataSet/train/images/000964_jpg.rf.1f5851d70989062f1a8212cd8c5cba98.jpg
#   inflating: /content/DataSet/train/images/001050_jpg.rf.2c992b7a9189095908c3e2382d87d625.jpg
#   inflating: /content/DataSet/train/images/001001_jpg.rf.6aa7ebb015698280450a909dae30aeca.jpg
#   inflating: /content/DataSet/train/images/001006_jpg.rf.6d020b6072e68b873f2d467c74878fbf.jpg
#   inflating: /content/DataSet/train/images/001021_jpg.rf.50b35d11a95eafb9ac5b76ab56fb9319.jpg
#   inflating: /content/DataSet/train/images/000993_jpg.rf.c7e3129f3ff8c5c3b8d4c63b364cdd92.jpg
#   inflating: /content/DataSet/train/images/000995_jpg.rf.6d9fbeec07f9092d9cc383c091a7105f.jpg
#   inflating: /content/DataSet/train/images/000991_JPG_jpg.rf.41682137cc72bc33c553a0608d67ae28.jpg
#   inflating: /content/DataSet/train/images/000977_JPG_jpg.rf.fcd34a60f5bb5e6e7c1f33179d497a71.jpg
#   inflating: /content/DataSet/train/images/000992_JPG_jpg.rf.c71a10268658043e3a37a53cca11410e.jpg
#   inflating: /content/DataSet/train/images/001005_jpg.rf.45fad92b3932af3165809652ad912c3a.jpg
#   inflating: /content/DataSet/train/images/000984_JPG_jpg.rf.31e4e92e04cc981e3fde5175e06a6716.jpg
#   inflating: /content/DataSet/train/images/000975_jpg.rf.acbef4163cd145df3ab8f1919d25bbaa.jpg
#   inflating: /content/DataSet/train/images/000979_JPG_jpg.rf.a6ad30a7171f547d3be0c6b22361a705.jpg
#   inflating: /content/DataSet/train/images/000983_jpg.rf.216ed1a6f362a0a5e85b2234cb5340e7.jpg
#   inflating: /content/DataSet/train/images/000972_jpg.rf.4a21793a291adc29282d8a81ca99c75e.jpg
#   inflating: /content/DataSet/train/images/000967_JPG_jpg.rf.8aa33cc1fce0934ea652d9583741474e.jpg
#   inflating: /content/DataSet/train/images/000994_JPG_jpg.rf.aa1d8f20da497d0afe54d4f457d37286.jpg
#   inflating: /content/DataSet/train/images/000975_JPG_jpg.rf.60191d369d94f6c602184fc26a2f8592.jpg
#   inflating: /content/DataSet/train/images/001002_jpg.rf.479a98cf05b7be47792d5fcf2ba69d5d.jpg
#   inflating: /content/DataSet/train/images/000981_JPG_jpg.rf.7bfe0d352b7648bf7ed24dcc1efaf780.jpg
#   inflating: /content/DataSet/train/images/000974_JPG_jpg.rf.8ad70abf525d6882ab0dad974577104c.jpg
#   inflating: /content/DataSet/train/images/000971_JPG_jpg.rf.3377746e6a9f741262f3eaf2b3d20986.jpg
#   inflating: /content/DataSet/train/images/000921_jpg.rf.7433111eb8aa0d47c863ee659bfefef1.jpg
#   inflating: /content/DataSet/train/images/000980_JPG_jpg.rf.adcff9ea13a54dbcfce0046bc9fde473.jpg
#   inflating: /content/DataSet/train/images/000997_jpg.rf.3800a42d9e57e9028c68f1bf3d89e425.jpg
#   inflating: /content/DataSet/train/images/001003_jpg.rf.3df40f6e24634c8887e9eb780f81325b.jpg
#   inflating: /content/DataSet/train/images/000925_JPG_jpg.rf.9c325aa0ee5d101bf3e8d7af0e588b7b.jpg
#   inflating: /content/DataSet/train/images/000968_JPG_jpg.rf.1242ddd64a8a9613f3b9837645edf535.jpg
#   inflating: /content/DataSet/train/images/000990_JPG_jpg.rf.8a830a5d2d0ee36b944ca0a0a606b293.jpg
#   inflating: /content/DataSet/train/images/000958_jpg.rf.cd8c952a82a07103cd42d77e7d34a19a.jpg
#   inflating: /content/DataSet/train/images/000979_jpg.rf.6cc5398e2440acdae8da8001c915676f.jpg
#   inflating: /content/DataSet/train/images/000920_JPG_jpg.rf.5068bbe2230c2ba818e00a45281bca1e.jpg
#   inflating: /content/DataSet/train/images/000998_JPG_jpg.rf.f1136b2578df0bae9525520406edb441.jpg
#   inflating: /content/DataSet/train/images/000918_JPG_jpg.rf.024b066b0f158df383c900c5586b5787.jpg
#   inflating: /content/DataSet/train/images/000929_jpg.rf.ef94c92cdf25119dd85c83a747d3c25b.jpg
#   inflating: /content/DataSet/train/images/000987_JPG_jpg.rf.1203dce6c7e1cec633aa56818dae9b54.jpg
#   inflating: /content/DataSet/train/images/001002_jpg.rf.3327b6dfe8ea80d47616db194512af95.jpg
#   inflating: /content/DataSet/train/images/000987_jpg.rf.e23849511b684a8dcc259f453c7c0410.jpg
#   inflating: /content/DataSet/train/images/000963_jpg.rf.9d7f3b77b528dbf06f5e3f9ca8fc2239.jpg
#   inflating: /content/DataSet/train/images/000934_jpg.rf.c502e55be21ba93997a2f03b920cbb26.jpg
#   inflating: /content/DataSet/train/images/000940_JPG_jpg.rf.705a5d92a79e80ec42159a5dd9255021.jpg
#   inflating: /content/DataSet/train/images/000951_JPG_jpg.rf.d1f5d45df30f9ae2cb5081a0d13d8de0.jpg
#   inflating: /content/DataSet/train/images/000930_JPG_jpg.rf.e138ff272a0b6eae2f6bc7218a4a6224.jpg
#   inflating: /content/DataSet/train/images/000948_JPG_jpg.rf.07e65e42c89183bec42352748c3a91de.jpg
#   inflating: /content/DataSet/train/images/000995_JPG_jpg.rf.35739e25102e09845b4da45a9c9e333b.jpg
#   inflating: /content/DataSet/train/images/000955_JPG_jpg.rf.0fc6fb888b23121c571e335dc5eef9ff.jpg
#   inflating: /content/DataSet/train/images/000937_JPG_jpg.rf.b7ed368a68f202e7343afd69be2393fa.jpg
#   inflating: /content/DataSet/train/images/000951_jpg.rf.3c44b320101f5ba60589a3d72a6994e4.jpg
#   inflating: /content/DataSet/train/images/000933_JPG_jpg.rf.67300e59730031f3248381bb2f87c0a3.jpg
#   inflating: /content/DataSet/train/images/000926_JPG_jpg.rf.6a59ba22c1ac983be75149f5b47a9c32.jpg
#   inflating: /content/DataSet/train/images/000933_jpg.rf.5075972accd1758656083e9f31966dd2.jpg
#   inflating: /content/DataSet/train/images/000960_JPG_jpg.rf.238dfb376869619a88166adcd2813dfe.jpg
#   inflating: /content/DataSet/train/images/000957_JPG_jpg.rf.f148f4373bbeb8e9cb897dfda5f68233.jpg
#   inflating: /content/DataSet/train/images/000928_jpg.rf.15203355f312884d6ad1d7e46329528c.jpg
#   inflating: /content/DataSet/train/images/000928_JPG_jpg.rf.a05ddf724162dc9ac0be8a23ffc5264e.jpg
#   inflating: /content/DataSet/train/images/000949_jpg.rf.5cb627592e154a6a6b98fdb5f1fea6aa.jpg
#   inflating: /content/DataSet/train/images/000956_JPG_jpg.rf.6f76d479d63ca7b1962bf423ae1c84fb.jpg
#   inflating: /content/DataSet/train/images/000962_jpg.rf.ce6de3b2e54850148f979de9359cf825.jpg
#   inflating: /content/DataSet/train/images/000919_JPG_jpg.rf.a9cf1e3930264edaf86475b1357a3a26.jpg
#   inflating: /content/DataSet/train/images/000925_jpg.rf.625ba383aba6e63158abf1028effdbbe.jpg
#   inflating: /content/DataSet/train/images/000924_JPG_jpg.rf.4256158e50cd3b3fa14542d6509dc033.jpg
#   inflating: /content/DataSet/train/images/000943_JPG_jpg.rf.7ba2b79b2c015edfd03197e2e9c7d009.jpg
#   inflating: /content/DataSet/train/images/000945_jpg.rf.aa8693d8dcfb67de03a2474e780ff00c.jpg
#   inflating: /content/DataSet/train/images/000920_jpg.rf.0d6f2f1456bad562a9b309abd7f72e3b.jpg
#   inflating: /content/DataSet/train/images/000931_JPG_jpg.rf.6394a453b21c03de64156c746d005e6c.jpg
#   inflating: /content/DataSet/train/images/000947_JPG_jpg.rf.84e4a3f41e37543598580c71b943e688.jpg
#   inflating: /content/DataSet/train/images/000962_JPG_jpg.rf.000e938b3d508690aa01a2b47d1174e7.jpg
#   inflating: /content/DataSet/train/images/000929_JPG_jpg.rf.520a0ffb894593c6beafefff0e8e8246.jpg
#   inflating: /content/DataSet/train/images/000888_JPG_jpg.rf.335ccec7ffec043689ca8c202da26a6a.jpg
#   inflating: /content/DataSet/train/images/000907_jpg.rf.fb135a5d49178273f8728239d9e0beb0.jpg
#   inflating: /content/DataSet/train/images/000932_jpg.rf.411514a68c8d0d434685a2508148588a.jpg
#   inflating: /content/DataSet/train/images/000922_jpg.rf.3ce7cc7e1b769a544c5f4132ce6b5757.jpg
#   inflating: /content/DataSet/train/images/000882_JPG_jpg.rf.746ba87faab6f1499c836a3f125ca60a.jpg
#   inflating: /content/DataSet/train/images/000942_JPG_jpg.rf.84c2f073dd1726b93ed1340bde94cee4.jpg
#   inflating: /content/DataSet/train/images/000884_jpg.rf.0bd369bbe12edb0a15bb1463c1d29e95.jpg
#   inflating: /content/DataSet/train/images/000953_JPG_jpg.rf.c8d53ae2ca7dc2b12209663260383731.jpg
#   inflating: /content/DataSet/train/labels/00014_00003_00002_png.rf.4fccdb75924e68eb29316a3981837e60.txt
#   inflating: /content/DataSet/train/labels/00014_00003_00014_png.rf.88766fa5191c38fb94b6d4dcc7ae120a.txt
#   inflating: /content/DataSet/train/images/000884_JPG_jpg.rf.fa1c3462e5005679bbcecca0690e6158.jpg
#   inflating: /content/DataSet/train/images/000958_JPG_jpg.rf.e8afa91f4dc4bd20bdf054d4241f8e37.jpg
#   inflating: /content/DataSet/train/labels/00014_00003_00021_png.rf.825991b529190ccf77bc56b9c61e2172.txt
#   inflating: /content/DataSet/train/images/000880_jpg.rf.c8e48c171bd4fe67895c9f81b277021c.jpg
#   inflating: /content/DataSet/train/images/000932_JPG_jpg.rf.a2e0972a5bb3d8c9d3db5f75438702d0.jpg
#   inflating: /content/DataSet/train/images/000938_jpg.rf.c49c7ac5cf146e6a6e65f651b00b7e39.jpg
#   inflating: /content/DataSet/train/labels/00014_00004_00011_png.rf.bad28eb9c1abe7d1f8069244457ab35f.txt
#   inflating: /content/DataSet/train/images/000913_JPG_jpg.rf.ea5913f7ca6692530f351cc4d2dec4f2.jpg
#   inflating: /content/DataSet/train/labels/00014_00003_00010_png.rf.e8a6a3396e3e79c3ec8d5147a85f7ef3.txt
#   inflating: /content/DataSet/train/images/000899_jpg.rf.af83211a57fb5b766959898013f9825d.jpg
#   inflating: /content/DataSet/train/labels/00014_00002_00021_png.rf.ff2ffc559276ccd66e9ab3c954223b7e.txt
#   inflating: /content/DataSet/train/images/000887_JPG_jpg.rf.985b664543e7aec7d7a94305b6af135f.jpg
#   inflating: /content/DataSet/train/images/000943_jpg.rf.5804c57584088d84e89f6214d8baa6aa.jpg
#   inflating: /content/DataSet/train/images/000883_jpg.rf.2989f344ac9b75da4aa7d9c7d6381975.jpg
#   inflating: /content/DataSet/train/labels/00014_00003_00011_png.rf.ecc21e0da3967e2030e2779f55c2a2bc.txt
#   inflating: /content/DataSet/train/images/000907_JPG_jpg.rf.4714f2b1decc93142c5d9e54d64c2297.jpg
#   inflating: /content/DataSet/train/labels/00014_00004_00004_png.rf.c53039b69ffc6b67bbabb3f1f998a481.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00025_png.rf.5e7574a0f5926c1c7beca45ea5b1a0ca.txt
#   inflating: /content/DataSet/train/images/000885_jpg.rf.c971cf62a82be66bb9a3c4df0162c783.jpg
#   inflating: /content/DataSet/train/labels/00014_00004_00013_png.rf.bb5751c1b9f28752c47d814013698dba.txt
#   inflating: /content/DataSet/train/labels/00014_00003_00005_png.rf.c6f91190add9bcc0fd26e93079d97f00.txt
#   inflating: /content/DataSet/train/labels/00014_00004_00015_png.rf.5100ac82f85e9a5dea501dfee72b2419.txt
#   inflating: /content/DataSet/train/labels/00014_00004_00007_png.rf.1fdb0886aacb4a3000adb8d17381595b.txt
#   inflating: /content/DataSet/train/images/000912_jpg.rf.a47d1fa8a66368c066835ba4540920d2.jpg
#   inflating: /content/DataSet/train/labels/00014_00003_00003_png.rf.4803eb03c627333bb0fa6a71d53f83a3.txt
#   inflating: /content/DataSet/train/images/000906_JPG_jpg.rf.02577dda8e09bf591c6165e3963f0ea3.jpg
#   inflating: /content/DataSet/train/images/000892_jpg.rf.fec54a08a388b703e070c88db056a3c8.jpg
#   inflating: /content/DataSet/train/images/000901_JPG_jpg.rf.5f0a3a8cdb1ad5caa1d715a9b2c079a2.jpg
#   inflating: /content/DataSet/train/images/000950_JPG_jpg.rf.9e1abf1c71b0cdaefd776fbbf51c1aa9.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00016_png.rf.540cfea58491ba4acf9a60b84bb74bb4.txt
#   inflating: /content/DataSet/train/images/000882_jpg.rf.f5d9732409ed9476b3d6e4b94ad80915.jpg
#   inflating: /content/DataSet/train/images/000885_JPG_jpg.rf.a5ae245deedd2d943ac87c052b29908d.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00004_png.rf.4e522edb03ebab2b01f1c598157e7b5d.txt
#   inflating: /content/DataSet/train/images/000910_jpg.rf.d6954141e998b59b3461a7f36cc1de14.jpg
#   inflating: /content/DataSet/train/images/000891_jpg.rf.4f982b26819294a8b9ad835d731dc8d4.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00017_png.rf.7cad8870d7521a5413ca7e0ddfb2867d.txt
#   inflating: /content/DataSet/train/labels/000139_jpg.rf.26619da85b0e7aeb5936e6f9862da9bb.txt
#   inflating: /content/DataSet/train/images/000896_JPG_jpg.rf.6f9797a98e484713cb121febfd3bbcbc.jpg
#   inflating: /content/DataSet/train/images/000886_JPG_jpg.rf.475975eb4dfce351357d5ee6b7075885.jpg
#   inflating: /content/DataSet/train/labels/00014_00002_00026_png.rf.981ccc943e267ee5331b8580e8639064.txt
#   inflating: /content/DataSet/train/images/000901_jpg.rf.cdaaaa9c0e800cce51da191e6f1af3c4.jpg
#   inflating: /content/DataSet/train/images/000892_JPG_jpg.rf.3763247bf8597df45262dd591e329310.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00029_png.rf.4d2cf1e04e270e982da770f0f252f6c8.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00007_png.rf.6e2a4e1fa32fe4c50eb5ab3ec6f755e6.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00013_png.rf.c1d8a01e0ebaa48e215725548fcb407c.txt
#   inflating: /content/DataSet/train/labels/00014_00002_00001_png.rf.9795200af7c32a3470c1ea0bfb73b2d2.txt
#   inflating: /content/DataSet/train/images/000906_jpg.rf.c95da7bb9eea7b1ae1b21362889e1b3e.jpg
#   inflating: /content/DataSet/train/images/000916_JPG_jpg.rf.313d80217bdda8b203b64e8b1a28e82d.jpg
#   inflating: /content/DataSet/train/images/000890_JPG_jpg.rf.a9ac6aad78458d5568d0459721d24939.jpg
#   inflating: /content/DataSet/train/labels/00014_00002_00003_png.rf.5da027596c7ed89359b1a18709afee5a.txt
#   inflating: /content/DataSet/train/labels/00014_00002_00005_png.rf.0870f1e372725a59a988801b499149fd.txt
#   inflating: /content/DataSet/train/images/000895_JPG_jpg.rf.fe575834a86bce903bd0d8b12c05aed7.jpg
#   inflating: /content/DataSet/train/images/000893_JPG_jpg.rf.def38b6094be1b7a6a3f4d0942f21cdb.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00027_png.rf.3f174fb72a9ff3ea24e36994ab5fd7c6.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00005_png.rf.b41a1968e4725119931312bc2abd63bb.txt
#   inflating: /content/DataSet/train/labels/00014_00000_00002_png.rf.7e5351b19af7fd927ab35133d60262c8.txt
#   inflating: /content/DataSet/train/labels/000143_jpg.rf.6140e35cc2a030831f3b3fe726088d9a.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00022_png.rf.7c9725e936250c6744b166886fe3319f.txt
#   inflating: /content/DataSet/train/labels/00014_00000_00022_png.rf.0a4baaf94dc5150ac353afc9ec67af7b.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00001_png.rf.d123474bf63fedfed1a6e420c850acb0.txt
#   inflating: /content/DataSet/train/images/000894_JPG_jpg.rf.5199fa65fe7a8015dd408d9201bff74d.jpg
#   inflating: /content/DataSet/train/labels/00014_00001_00014_png.rf.dd31f58ccf405ac5dea5dc10bfca1d00.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00021_png.rf.db62d8c6bb811168923ba6719d73b06c.txt
#   inflating: /content/DataSet/train/labels/000148_jpg.rf.b062ff7b34f4d4dba2b43ae4d02ef5d1.txt
#   inflating: /content/DataSet/train/labels/00014_00002_00002_png.rf.e248f64edf7f056d062337564eb61466.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00003_png.rf.fa2fe5dd06beb2467aec162062f91219.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00023_png.rf.632cea9b5e8d0d8390af38e41d42c5d5.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00008_png.rf.58d6e0f98dbcdcaa44ce50a3fc3e18a2.txt
#   inflating: /content/DataSet/train/labels/000144_jpg.rf.46169b9b9f1e346a087b5afe61625e96.txt
#   inflating: /content/DataSet/train/labels/000142_jpg.rf.513cc77ba5a8393ad5790074e9e23d25.txt
#   inflating: /content/DataSet/train/labels/00014_00000_00025_png.rf.5ea9f6625a899eefe4cee038c8e81e4d.txt
#   inflating: /content/DataSet/train/labels/000136_jpg.rf.8ca8acdf2a3f2754a7f5582a9e95d15f.txt
#   inflating: /content/DataSet/train/images/000914_jpg.rf.27e12f621c6b61503ffdfe79a929892d.jpg
#   inflating: /content/DataSet/train/labels/000124_jpg.rf.b2d7fb70bd6a2afef4d709188bd1d410.txt
#   inflating: /content/DataSet/train/labels/00014_00000_00000_png.rf.47478fea4d91b2043525566061f32baa.txt
#   inflating: /content/DataSet/train/labels/000138_jpg.rf.a81b71498711ea0028f8eab06f5f87f6.txt
#   inflating: /content/DataSet/train/labels/000112_jpg.rf.dd7feff0071abf97736132a43ebe4435.txt
#   inflating: /content/DataSet/train/labels/000128_jpg.rf.3c4492780bef60bef93cfda0ddbe00b7.txt
#   inflating: /content/DataSet/train/labels/000133_jpg.rf.b30c15f77ef7e9aefce858312816baf4.txt
#   inflating: /content/DataSet/train/labels/000135_jpg.rf.a7eeb674579d144f7473548e2f1dbdb4.txt
#   inflating: /content/DataSet/train/labels/000120_jpg.rf.b6ab326eec167beedd36a65f7d800288.txt
#   inflating: /content/DataSet/train/labels/000114_jpg.rf.5113f33fc1a33775ba6d888a651c0167.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00015_png.rf.d1c85e6af81c6550bca7b5df191e3d65.txt
#   inflating: /content/DataSet/train/labels/00014_00001_00028_png.rf.d56bcd8f02ada02ce1a496a5d26801f9.txt
#   inflating: /content/DataSet/train/labels/000108_jpg.rf.db0f3deb9abf893719bef6f4b72119d6.txt
#   inflating: /content/DataSet/train/labels/000146_jpg.rf.215ccdfd29787cdb48eb81aaee5a1db7.txt
#   inflating: /content/DataSet/train/images/000900_JPG_jpg.rf.0e74c0ba2174d11700b360e242768985.jpg
#   inflating: /content/DataSet/train/labels/000096_jpg.rf.6ee3946f06df5359e8a4b6ecd632bda9.txt
#   inflating: /content/DataSet/train/labels/000113_jpg.rf.e26b611dceceb9de11bd3f9610e548da.txt
#   inflating: /content/DataSet/train/labels/000106_jpg.rf.dc73ea44c865f624c1649fafa886c232.txt
#   inflating: /content/DataSet/train/labels/00008_00046_00027_png.rf.6f2775c315d3775c7e9eaba517d7ff08.txt
#   inflating: /content/DataSet/train/labels/000105_jpg.rf.00fc36b9ec4dea19c90e0f8e0ec2787d.txt
#   inflating: /content/DataSet/train/labels/00014_00002_00000_png.rf.51bf5179a13a3014e9624675dce843c0.txt
#   inflating: /content/DataSet/train/labels/000090_jpg.rf.5aef5aaf638ba2c7887ce93bef548120.txt
#   inflating: /content/DataSet/train/labels/000109_jpg.rf.dc15d815b99240965e6ead9c0b02762d.txt
#   inflating: /content/DataSet/train/labels/000141_jpg.rf.0cbb27064af2c5cd3c9aa66271da5b71.txt
#   inflating: /content/DataSet/train/labels/000102_jpg.rf.471b3106e922f0c2dce074cbd1e62f25.txt
#   inflating: /content/DataSet/train/labels/000094_jpg.rf.d258bac58a5d4910bd9405384854f0fb.txt
#   inflating: /content/DataSet/train/labels/000107_jpg.rf.dc0b13f2e13412f678854a1b82eaedfc.txt
#   inflating: /content/DataSet/train/labels/000101_jpg.rf.4447357576dd6824a80d457eba359f95.txt
#   inflating: /content/DataSet/train/labels/000127_jpg.rf.90962d369afe6e4f735f5335de47a683.txt
#   inflating: /content/DataSet/train/labels/000126_jpg.rf.6fe20cc6b8029afb1c535dca78477857.txt
#   inflating: /content/DataSet/train/labels/000115_jpg.rf.00b3095542149119936c95494114bbe2.txt
#   inflating: /content/DataSet/train/labels/000119_jpg.rf.16e2991fb0f575fb737cc37566713135.txt
#   inflating: /content/DataSet/train/labels/000116_jpg.rf.a2c10a1451e9b404906b1883205020c2.txt
#   inflating: /content/DataSet/train/labels/000134_jpg.rf.06aa6db5b5b8b12499da10c7262a9dd5.txt
#   inflating: /content/DataSet/train/labels/000103_jpg.rf.7328bc6f71ee977366d9d210978d674b.txt
#   inflating: /content/DataSet/train/labels/00008_00034_00017_png.rf.a8cdc14f60da89cfae5210dbc02095b8.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00029_png.rf.ea722d02226285b0bdbe5c8e0e13fb6c.txt
#   inflating: /content/DataSet/train/labels/00008_00043_00021_png.rf.643af33f4cce2ec8d7e8b1697fe0f95d.txt
#   inflating: /content/DataSet/train/labels/000110_jpg.rf.23692830a54dd96a404f9e0622299e48.txt
#   inflating: /content/DataSet/train/labels/00008_00039_00011_png.rf.feeb21685f9e69f9905a68d8acd70583.txt
#   inflating: /content/DataSet/train/labels/000118_jpg.rf.572144371ee15559c337c4392e9f521c.txt
#   inflating: /content/DataSet/train/labels/00008_00036_00018_png.rf.924579c4a9ffa5222ee4893b6b1a0ba3.txt
#   inflating: /content/DataSet/train/labels/000125_jpg.rf.328e727630cca616076a46a96c3c05fc.txt
#   inflating: /content/DataSet/train/labels/00008_00046_00017_png.rf.dd4b0347a1f8810cd6a82325de26727c.txt
#   inflating: /content/DataSet/train/labels/000095_jpg.rf.df1e3ee32745f79306224eeb192b141b.txt
#   inflating: /content/DataSet/train/labels/00008_00036_00007_png.rf.2ece06bd0fe4de29fc3f5cb9b38e4d50.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00019_png.rf.7fd367b2a5408c087b61941ac0254945.txt
#   inflating: /content/DataSet/train/labels/00008_00037_00015_png.rf.b5d036ebef2011b1d5db1ef6d76e2b27.txt
#   inflating: /content/DataSet/train/labels/00008_00039_00013_png.rf.e6318d5fa253ff94ebb884709ec5964a.txt
#   inflating: /content/DataSet/train/labels/00008_00045_00015_png.rf.6b7c895c69eee4f69bf7ce20bf13b51a.txt
#   inflating: /content/DataSet/train/labels/00008_00044_00011_png.rf.cd0fdf2f5f6922b166ca8b3c0e968e63.txt
#   inflating: /content/DataSet/train/labels/00008_00045_00008_png.rf.82db95f04f079611574c84381458f783.txt
#   inflating: /content/DataSet/train/labels/000122_jpg.rf.5dcc5f09910afa2c3595fe456d75e349.txt
#   inflating: /content/DataSet/train/labels/00008_00043_00016_png.rf.60be159523f81d53a9fcf46d8a2d5425.txt
#   inflating: /content/DataSet/train/labels/00008_00044_00014_png.rf.d4a3e65cd41f77a7b33219d20b9fd78f.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00021_png.rf.ba7e98a109a3dac8169b637c1fd7a32f.txt
#   inflating: /content/DataSet/train/labels/00008_00044_00016_png.rf.1ecc3e97fb6f3484ab4e908c210dca75.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00018_png.rf.f3b43669e52b97b0728e81be1970cbcc.txt
#   inflating: /content/DataSet/train/labels/000097_jpg.rf.1423b4397b7a16f38e6c5136b3a647d4.txt
#   inflating: /content/DataSet/train/labels/00008_00018_00001_png.rf.0a707745803e8daca115c8297889dc64.txt
#   inflating: /content/DataSet/train/labels/00008_00044_00012_png.rf.9f6014b383cca09283334864ff8ea1d1.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00020_png.rf.b9212bfe950b0d3dd91a63a3486e460a.txt
#   inflating: /content/DataSet/train/labels/00008_00026_00008_png.rf.10952d3878d1dc4ab460bc9b2dc168bc.txt
#   inflating: /content/DataSet/train/labels/00008_00022_00013_png.rf.e96f62b6decd362dd6b3cfa498b87add.txt
#   inflating: /content/DataSet/train/labels/00008_00038_00007_png.rf.1381085ca95df89b4b0f7b8011598f1f.txt
#   inflating: /content/DataSet/train/labels/00008_00022_00011_png.rf.162f71e51ca4a63781a5c9b109f8188e.txt
#   inflating: /content/DataSet/train/labels/00008_00036_00019_png.rf.40deb282b0e09eb834b0c69852160e42.txt
#   inflating: /content/DataSet/train/labels/00008_00036_00008_png.rf.abf8fcc7fe43e0ffbb38f9c095c2b939.txt
#   inflating: /content/DataSet/train/labels/00008_00021_00010_png.rf.6697ebda649d383f15e2f82500f2249d.txt
#   inflating: /content/DataSet/train/labels/00008_00034_00007_png.rf.08a62227cc74501de6baeb62505431db.txt
#   inflating: /content/DataSet/train/labels/00008_00022_00021_png.rf.bea97226747e7cf474e0fc090b934ee1.txt
#   inflating: /content/DataSet/train/labels/00008_00029_00010_png.rf.97e2b4ea12a2d1cf4660cf96aa398bde.txt
#   inflating: /content/DataSet/train/labels/00008_00039_00023_png.rf.e13549c267c786352c4340ec0a98c110.txt
#   inflating: /content/DataSet/train/labels/00008_00017_00023_png.rf.4e62fa0b1e9860ed7ef6fcb473637736.txt
#   inflating: /content/DataSet/train/labels/00008_00029_00009_png.rf.4f8b73e87636d8c00e70f2f6e202f76a.txt
#   inflating: /content/DataSet/train/labels/00008_00034_00005_png.rf.a43fabd4184e306626ec7f7b8d9cb655.txt
#   inflating: /content/DataSet/train/labels/00008_00031_00015_png.rf.72cde591323fef49ef9b73f2e2b087ab.txt
#   inflating: /content/DataSet/train/labels/00008_00043_00023_png.rf.f1f8c8e1d4b1b051a49833ccd4b989fe.txt
#   inflating: /content/DataSet/train/labels/00008_00021_00018_png.rf.f3f32930ab55fa2873e2b34789256e1a.txt
#   inflating: /content/DataSet/train/labels/00008_00029_00020_png.rf.b53d4a7d5f7a2945fe5e48b9badfade3.txt
#   inflating: /content/DataSet/train/labels/00008_00035_00015_png.rf.0b5a52b94fe5d1c59a12d2e7784662c8.txt
#   inflating: /content/DataSet/train/labels/00008_00015_00019_png.rf.0bddfbd3aa4b32af5a0533da350737e0.txt
#   inflating: /content/DataSet/train/labels/00008_00039_00012_png.rf.474e01189d0471bea8f8874897477064.txt
#   inflating: /content/DataSet/train/labels/00008_00033_00020_png.rf.037dde83c824b4fcd89da3748f6ffaa3.txt
#   inflating: /content/DataSet/train/labels/00008_00019_00015_png.rf.497e0b25e47009bec0af274f66878ff6.txt
#   inflating: /content/DataSet/train/labels/00008_00020_00013_png.rf.4d8d4e6e7d0c2b0c8843f345d25491ce.txt
#   inflating: /content/DataSet/train/labels/00008_00018_00000_png.rf.7a5b4f483174c264c423b081d9a0e39c.txt
#   inflating: /content/DataSet/train/labels/00008_00015_00024_png.rf.af4a1d17536fb0c66a949fe5e8b95306.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00006_png.rf.d02cdcae0093132e60a187d264204dbe.txt
#   inflating: /content/DataSet/train/labels/00008_00032_00017_png.rf.9b8dcde884e525e549fc1397c92f9043.txt
#   inflating: /content/DataSet/train/labels/00008_00030_00021_png.rf.6d2daaa810b341dd9c92d2f171f1f6dd.txt
#   inflating: /content/DataSet/train/labels/00008_00020_00010_png.rf.dfd96c5ce7ce327f281398842762fbb2.txt
#   inflating: /content/DataSet/train/labels/00008_00032_00027_png.rf.df8821a2d1b1472ce64f49ed1c1667dc.txt
#   inflating: /content/DataSet/train/labels/00008_00024_00018_png.rf.fed7a1841e3c2f10903ec89882f32fcc.txt
#   inflating: /content/DataSet/train/labels/00008_00031_00013_png.rf.0886c698e7801ec5d475e7a59f3dacc9.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00025_png.rf.4c94f0a2f88e0ea8957494fe6a716dc8.txt
#   inflating: /content/DataSet/train/labels/00008_00021_00017_png.rf.a4ad4c741ea2569a9fb92926ae0d3038.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00020_png.rf.5d93b897eff87e2b8ebf74c791e24268.txt
#   inflating: /content/DataSet/train/labels/00008_00030_00024_png.rf.604f33c7fdf8d8a3cda6a20b9d0332e6.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00017_png.rf.714a968b88c09936e2f58f86b8a7cc3e.txt
#   inflating: /content/DataSet/train/labels/00008_00009_00022_png.rf.e5e73dae4047304a524b6bd102fa89a3.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00007_png.rf.0d06f3d3ba180daeb084ea1043b9ca43.txt
#   inflating: /content/DataSet/train/labels/00008_00013_00020_png.rf.b476c774cc9b0c9ede53017af3607af4.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00003_png.rf.65ca0fe542b187065fe29cee929535ea.txt
#   inflating: /content/DataSet/train/labels/00008_00021_00019_png.rf.879b7186231fddc0b0cae337c06fc04b.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00010_png.rf.27b69a2d31aff1ff5ae9dad883cda278.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00000_png.rf.9faeda3aca8d35dd95a55fb0f64f3d71.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00020_png.rf.bb33863efda134bd0126a31c071c136b.txt
#   inflating: /content/DataSet/train/labels/00008_00013_00009_png.rf.ed9a4e669d93ec49a48dae3891b7fe87.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00010_png.rf.a2a6c21b759d8bfe0c9db6d7a0335a21.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00009_png.rf.9403edeb2431ddaf3a85ad6f4eb028cf.txt
#   inflating: /content/DataSet/train/labels/00008_00010_00025_png.rf.d4f4f374b6127660900f398184945e74.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00012_png.rf.7442e1750ce9c73a16263c80a35ca772.txt
#   inflating: /content/DataSet/train/labels/00008_00020_00004_png.rf.53e1092e238f3170c0532a48596db52e.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00021_png.rf.92b4e6c0c3ed39d223b7d05b8248dd88.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00009_png.rf.ceff3012182589be628bad6d66531ea9.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00005_png.rf.426bfb68fffacaec141e6912e4a2aced.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00004_png.rf.8af5a7b7857f3ea8b94bfb037ebadcfa.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00008_png.rf.95ddf01d60917a6ccaa8b37d9f273d8e.txt
#   inflating: /content/DataSet/train/labels/00008_00032_00018_png.rf.2eb6ea318be58a2350056aaabb6707a1.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00005_png.rf.64257d3a3a7a6decb2cc6371a7f8e13a.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00013_png.rf.c842a02cc7f62236d5b23face70fb396.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00011_png.rf.f304d2c1cd2384c87f607f0202078932.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00012_png.rf.338d52595eea18520985f947fc05d3d5.txt
#   inflating: /content/DataSet/train/labels/00007_00043_00023_png.rf.feb562cfd626e2c922bfefe60f777ffb.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00015_png.rf.3e9627fb36483d92bb4002f27e3b7b1a.txt
#   inflating: /content/DataSet/train/labels/00008_00011_00019_png.rf.1646f5f156c9e094dd9ad224a37b0e83.txt
#   inflating: /content/DataSet/train/labels/00008_00006_00017_png.rf.f7b12167002609252e21ada42fe8141d.txt
#   inflating: /content/DataSet/train/labels/00008_00004_00020_png.rf.70461d631adaa4613b97abbde3dcca62.txt
#   inflating: /content/DataSet/train/labels/00008_00001_00018_png.rf.706a156058bdbc1fad6bafe5685e41dc.txt
#   inflating: /content/DataSet/train/labels/00008_00015_00008_png.rf.2a4cf2d185ea7b9a3615b0f455572f78.txt
#   inflating: /content/DataSet/train/labels/000083_jpg.rf.4ac9cff16128eeb88a8dcb6b4fcceb21.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00024_png.rf.457b7ec0be8a1ac20238f890b9122689.txt
#   inflating: /content/DataSet/train/labels/00008_00010_00015_png.rf.f4a082367668bbe31905c10ddf009dc8.txt
#   inflating: /content/DataSet/train/labels/00008_00005_00012_png.rf.929d0c3a63b135e8ce424f36e739c3ed.txt
#   inflating: /content/DataSet/train/labels/00008_00006_00015_png.rf.0120db0f81671ac2fa8a4a99552bc379.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00001_png.rf.7905e65bd51cb27f960c0859fb14b4c5.txt
#   inflating: /content/DataSet/train/labels/000085_jpg.rf.0d89f49611799c63ce6135095b91b3a5.txt
#   inflating: /content/DataSet/train/labels/000089_jpg.rf.bfd277d09a9b2dc80ada6d3632123b60.txt
#   inflating: /content/DataSet/train/labels/00008_00007_00016_png.rf.47b19f609a038649b680c4221d103647.txt
#   inflating: /content/DataSet/train/labels/00008_00012_00014_png.rf.4391184a95a36f7f673f1a916d564333.txt
# ...
#   inflating: /content/DataSet/valid/labels/000721_jpg.rf.933725532705bbd7964667ffb599ae8c.txt
#   inflating: /content/DataSet/valid/labels/000744_jpg.rf.3a88e46bcbd6377255d7a951769ce015.txt
#   inflating: /content/DataSet/valid/labels/000773_jpg.rf.111fbb03a2a0b7938ea745467749d021.txt
#   inflating: /content/DataSet/valid/labels/000567_jpg.rf.1cd65f0778ff6ceff0f43ff1710c384f.txt
#   inflating: /content/DataSet/valid/labels/000492_jpg.rf.378175376b4c76fbf8bf8cb71c5a983c.txt
#   inflating: /content/DataSet/valid/labels/000387_jpg.rf.7119e3f9c6a97ec54b1de9f62fd6f7b2.txt
#   inflating: /content/DataSet/valid/labels/000794_jpg.rf.d5da386085366607e8c92c0e564dec3c.txt
#   inflating: /content/DataSet/valid/labels/000661_jpg.rf.883d895f9dab5e9c4d081aba15c224e9.txt
#   inflating: /content/DataSet/valid/labels/000434_jpg.rf.10ecc3b6b80b17f6792a4fb7939437ca.txt
#   inflating: /content/DataSet/valid/labels/000516_jpg.rf.b0df60d28c0403cd3d0d8a2f9bcd2506.txt
#   inflating: /content/DataSet/valid/labels/000413_jpg.rf.669b3ac51f4fee4f4df7766754610121.txt
#   inflating: /content/DataSet/valid/labels/000460_jpg.rf.3be56562d86269ad806603bb1cdb710c.txt
#   inflating: /content/DataSet/valid/labels/000420_jpg.rf.0f91560519dbea3e36a02a20f10ec48b.txt
#   inflating: /content/DataSet/valid/labels/000450_jpg.rf.8dbe8ff0fd011220d307b9d8fe745323.txt
#   inflating: /content/DataSet/valid/labels/000474_jpg.rf.f9faa49f328b0810666ae1103e819a7f.txt
#   inflating: /content/DataSet/valid/labels/000471_jpg.rf.7cff1942730924579c87c484642b6e9f.txt
#   inflating: /content/DataSet/valid/labels/000353_jpg.rf.9da320bfbb4f4b6d2ec25b69a0be7f06.txt
#   inflating: /content/DataSet/valid/labels/000354_jpg.rf.b7ccfe0e9fd239ec28a6518202c7c531.txt
#   inflating: /content/DataSet/valid/labels/000363_jpg.rf.ed6453a9c64ca832ebf1b36aa5a50907.txt
#   inflating: /content/DataSet/valid/labels/000521_jpg.rf.0deed514852fbf84e58eea8289f5339e.txt
#   inflating: /content/DataSet/valid/labels/000470_jpg.rf.c46a76f9f37d561bd7021182dad60a4c.txt
#   inflating: /content/DataSet/valid/labels/000399_jpg.rf.db38c5d43dc8f412c03578dbabae5d19.txt
#   inflating: /content/DataSet/valid/labels/000456_jpg.rf.afad59663b563575264001ee039d2168.txt
#   inflating: /content/DataSet/valid/labels/000432_jpg.rf.24bdf904d16f60471490456f826ee193.txt
#   inflating: /content/DataSet/valid/labels/000373_jpg.rf.f6a0fe844051159b218ed37511a14a7c.txt
#   inflating: /content/DataSet/valid/labels/000491_jpg.rf.c237338f2d048f5f0326a2d4156ec65c.txt
#   inflating: /content/DataSet/valid/labels/000476_jpg.rf.20e99f8a70b94c7a71d36cde8c333ec4.txt
#   inflating: /content/DataSet/valid/labels/000461_jpg.rf.beeb2bc233e2f5893d128e0a7eea18d8.txt
#   inflating: /content/DataSet/valid/labels/000203_jpg.rf.39acec1ffdf2d6493cb3c0c099cec7a3.txt
#   inflating: /content/DataSet/valid/labels/000435_jpg.rf.14bc5d69fce5237cc7bf63668f861345.txt
#   inflating: /content/DataSet/valid/labels/000996_JPG_jpg.rf.4d705f3b6d2ed49e0641ee8ac23488d4.txt
#   inflating: /content/DataSet/valid/labels/000525_jpg.rf.b6c20ac9c71c2b22aa23509053f69b84.txt
#   inflating: /content/DataSet/valid/labels/000707_jpg.rf.425d3bbda0d5bfb0e541cdfb6631d8a4.txt
#   inflating: /content/DataSet/valid/labels/000394_jpg.rf.207625ae162416a9c54677d3dfb6e111.txt
#   inflating: /content/DataSet/valid/labels/000208_jpg.rf.832e26c0ed8a8bd11d3f9a9e3a49c98a.txt
#   inflating: /content/DataSet/valid/labels/000154_jpg.rf.10e8182b19d397c1a3fc5496f48956c6.txt
#   inflating: /content/DataSet/valid/labels/000242_jpg.rf.ce0b1a3828ba64c185b3638cd90951c6.txt
#   inflating: /content/DataSet/valid/labels/000290_jpg.rf.e54ac541fdeec4fd02628d7930a30ad0.txt
#   inflating: /content/DataSet/valid/labels/000269_jpg.rf.4e2a4c97538137c2c4d881ec4cba4201.txt
#   inflating: /content/DataSet/valid/labels/000371_jpg.rf.d2f84e3f3e15cea3038a66be160e894f.txt
#   inflating: /content/DataSet/valid/labels/000498_jpg.rf.3a2dc5e243040ff3b2584564a411d3dc.txt
#   inflating: /content/DataSet/valid/labels/000437_png_jpg.rf.5be9f4fe4b3f2ebc8ed2954d09d791bf.txt
#   inflating: /content/DataSet/valid/labels/000401_jpg.rf.d08904263e901566fa23580df75bfd52.txt
#   inflating: /content/DataSet/valid/labels/000330_jpg.rf.e8b0af092d57c4f34925bb7177a0b474.txt
#   inflating: /content/DataSet/valid/labels/000263_jpg.rf.889dadf72dd7aa18c6b94c961b419c6a.txt
#   inflating: /content/DataSet/valid/labels/000348_jpg.rf.df4749301a69a49513ab3c77b76c6ba5.txt
#   inflating: /content/DataSet/valid/labels/000254_jpg.rf.755554d1fb284c7152b5e2b32cda8aa5.txt
#   inflating: /content/DataSet/valid/labels/000161_jpg.rf.ae64f76d8ef6076b247838f85e05de8f.txt
#   inflating: /content/DataSet/valid/labels/000164_jpg.rf.4299a2cf7fe633528bda8e6c82bba7e0.txt
#   inflating: /content/DataSet/valid/labels/000297_jpg.rf.b373c5e86c5e0fcfe7a99082beeba1d2.txt
#   inflating: /content/DataSet/valid/labels/000159_jpg.rf.1453deeb1721dd612b3e4c6ec33da5d8.txt
#   inflating: /content/DataSet/valid/labels/000219_jpg.rf.95e9f863927a6517eb4e7c3f866099c4.txt
#   inflating: /content/DataSet/valid/labels/000249_jpg.rf.ce8b13229bd03d29238b79ffa6cc50c5.txt
#   inflating: /content/DataSet/valid/labels/00014_00010_00001_png.rf.68c586d3ac58ed9ad2b5b51c2702b4cf.txt
#   inflating: /content/DataSet/valid/labels/00014_00022_00001_png.rf.5f053622d21d091f24ead75941f99403.txt
#   inflating: /content/DataSet/valid/labels/000463_png_jpg.rf.90ac8516e2d1a9a7999901c883dcd2a1.txt
#   inflating: /content/DataSet/valid/labels/000160_jpg.rf.63f912a8062e2c8868e97ab5fd14d647.txt
#   inflating: /content/DataSet/valid/labels/000299_jpg.rf.37004e619318422c6e11e4db672b5a37.txt
#   inflating: /content/DataSet/valid/labels/000339_jpg.rf.09a46fe4f8a60c2703ab35a8d982461e.txt
#   inflating: /content/DataSet/valid/labels/000165_jpg.rf.e9dabfaaf12417e2ba0ac7ec3127c251.txt
#   inflating: /content/DataSet/valid/labels/000319_jpg.rf.1fd32a8ec85d8ece29bdcc792fdf960c.txt
#   inflating: /content/DataSet/valid/labels/00014_00021_00022_png.rf.27134343f93653de165a17037bfb73c6.txt
#   inflating: /content/DataSet/valid/labels/000221_jpg.rf.78710a088f811620a5953e13bd972228.txt
#   inflating: /content/DataSet/valid/labels/000187_jpg.rf.a4e0eb7a38e4d4cadcef43e381a0f033.txt
#   inflating: /content/DataSet/valid/labels/000197_jpg.rf.c3fc560c02bac1c6baeec423405f5c24.txt
#   inflating: /content/DataSet/valid/labels/00014_00023_00021_png.rf.0a4585c02901034383d98335603ed09d.txt
#   inflating: /content/DataSet/valid/labels/000311_jpg.rf.92fb3e611aa56284af5fd4765e5368d3.txt
#   inflating: /content/DataSet/valid/labels/00014_00011_00013_png.rf.5c38fd5ec4ddf261665eb299b209c6cd.txt
#   inflating: /content/DataSet/valid/labels/000352_jpg.rf.d63e34658183df08ad20ef345a34795f.txt
#   inflating: /content/DataSet/valid/labels/000264_jpg.rf.6876ea6d3378e9d03db30c2183cc5045.txt
#   inflating: /content/DataSet/valid/labels/000176_jpg.rf.96cf6ceea532f7e4169a4cea717a6219.txt
#   inflating: /content/DataSet/valid/labels/00014_00018_00009_png.rf.2d72ed302f587a671e54afaf1a09a0a9.txt
#   inflating: /content/DataSet/valid/labels/000806_jpg.rf.6231e471fcf0e8949c69ed74a31f5a16.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00017_png.rf.4d7c1e9d049e8a66cfdc576ed88b5fca.txt
#   inflating: /content/DataSet/valid/labels/00014_00012_00029_png.rf.366e398c9dd622533fd1892f9d836749.txt
#   inflating: /content/DataSet/valid/labels/00014_00007_00015_png.rf.821ef95c005fbfbbe0c74db69cd18063.txt
#   inflating: /content/DataSet/valid/labels/00014_00013_00007_png.rf.d6d53f7f5f8d66a0f726fda36931a444.txt
#   inflating: /content/DataSet/valid/labels/000959_JPG_jpg.rf.2f6359d6921e833a4c769a41ea5a5f35.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00023_png.rf.7f736e938225b82a2984aa0f3e8de55c.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00005_png.rf.e3aaedc6dac0cc23af08380064bf51f1.txt
#   inflating: /content/DataSet/valid/labels/00014_00010_00004_png.rf.fce7bd5dcff83a6e6634b19b9b8d00d0.txt
#   inflating: /content/DataSet/valid/labels/00014_00013_00010_png.rf.0358de740627248f20390ba5887f0ae0.txt
#   inflating: /content/DataSet/valid/labels/00014_00023_00014_png.rf.4f936a83f573af4da01d2c99bd65257c.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00026_png.rf.038e8ad38151a8f6155603801aa4e2bd.txt
#   inflating: /content/DataSet/valid/labels/00014_00007_00018_png.rf.b1a6bc22dfa2520a4f80c645087c38d9.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00021_png.rf.86ee460f79a2e8a2d702df174c862850.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00002_png.rf.f35bed5e27fca545a320efeb4b5d81d0.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00012_png.rf.277d9f2527db84cf64fed938bfe0eb22.txt
#   inflating: /content/DataSet/valid/labels/00014_00013_00005_png.rf.7afaaa7763228bd8062f208657493059.txt
#   inflating: /content/DataSet/valid/labels/00014_00007_00014_png.rf.5cbe0ea73b96ee9d4b867745a985f415.txt
#   inflating: /content/DataSet/valid/labels/00014_00023_00012_png.rf.b5d04ed4520fe1613bacb494db5d350f.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00012_png.rf.c1a1182ffbc57148f9b5af2978833fe1.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00010_png.rf.eaf26fb45c806ade178b403b585eeb40.txt
#   inflating: /content/DataSet/valid/labels/000158_jpg.rf.de2717752337de37af3909a837ac1ecd.txt
#   inflating: /content/DataSet/valid/labels/00014_00007_00010_png.rf.897d67a41c1b075c2ce0de6658c78d12.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00015_png.rf.7deb3d52b8955c9f16bc4630ca2b3a09.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00025_png.rf.9f597254f67382352eda6f7bf0ccfe90.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00012_png.rf.02ffbac072397fe4f36979ba80f74fb9.txt
#   inflating: /content/DataSet/valid/labels/00014_00007_00016_png.rf.5d7823090d0693e49c7a082833e25966.txt
#   inflating: /content/DataSet/valid/labels/00014_00010_00006_png.rf.fc6789dfb26ab8b258a45781c138f7d8.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00000_png.rf.1177c6754fd20cd5a21a584c1288b2d7.txt
#   inflating: /content/DataSet/valid/labels/00014_00010_00000_png.rf.a400f3cc1c01ae5b1e410948f7919e92.txt
#   inflating: /content/DataSet/valid/labels/00014_00009_00004_png.rf.73407ef1038d43d87b332be788574a66.txt
#   inflating: /content/DataSet/valid/labels/000104_jpg.rf.84bfd7deb7e3d5f06dc8284e8c40b521.txt
#   inflating: /content/DataSet/valid/labels/00014_00003_00018_png.rf.f11abf60a9170d4baaa8874052e0834c.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00016_png.rf.061a46c5693825f6713422588d66f049.txt
#   inflating: /content/DataSet/valid/labels/000131_jpg.rf.d5b08b4a7d3727786a522ed886d962e6.txt
#   inflating: /content/DataSet/valid/labels/000137_jpg.rf.4417be60e5e8d0047af644d961795c36.txt
#   inflating: /content/DataSet/valid/labels/00014_00006_00024_png.rf.11a28415ccf012da42d0b3a2845ff647.txt
#   inflating: /content/DataSet/valid/labels/00014_00008_00006_png.rf.e6ce907e9d1c78a8eea7b39d096b66cc.txt
#   inflating: /content/DataSet/valid/labels/000320_jpg.rf.62b5a7f335fc5e0c633774c04d7d7088.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00027_png.rf.6adc795f986a59944a3555bca3a3d8f6.txt
#   inflating: /content/DataSet/valid/labels/000111_jpg.rf.e60c5cd270ea82c644bdfc2ee629daef.txt
#   inflating: /content/DataSet/valid/labels/00014_00006_00002_png.rf.5bf0c54cbd123c81f18c19973e068111.txt
#   inflating: /content/DataSet/valid/labels/00014_00003_00008_png.rf.cd8a887922aeb3c34252bd39a11814f2.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00006_png.rf.5497c0df08cb437fb189487bf59888c0.txt
#   inflating: /content/DataSet/valid/labels/00008_00038_00009_png.rf.12ba1188789e6b6747031686b0576a20.txt
#   inflating: /content/DataSet/valid/labels/000123_jpg.rf.d05325e5ae61a1b2cf969df6389c899c.txt
#   inflating: /content/DataSet/valid/labels/00014_00005_00006_png.rf.9d23cd4be31c691050beba74e43087f0.txt
#   inflating: /content/DataSet/valid/labels/000140_jpg.rf.e9eafc934e46f0cd62b6e05d4c614d79.txt
#   inflating: /content/DataSet/valid/labels/00008_00005_00016_png.rf.0dc3f1206158857c75c6ad29d422dd99.txt
#   inflating: /content/DataSet/valid/labels/00014_00005_00007_png.rf.b4ff08928208b2ec89580e7472731da0.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00009_png.rf.b6c7914d29ef0fac4d1f33a3309134cd.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00017_png.rf.16e5837331428c915db71c9b93452ce2.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00016_png.rf.97d3529a5693c4808581f582f6d567ee.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00001_png.rf.fbaefc1fdb2f042c76b8b203a140a043.txt
#   inflating: /content/DataSet/valid/labels/00014_00001_00012_png.rf.72aca827b504a1531fc88c801b17af55.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00020_png.rf.710887530cbc8299c39440e19f6df948.txt
#   inflating: /content/DataSet/valid/labels/000149_jpg.rf.b30519cf48fdf6e879c724a7e5a3d24c.txt
#   inflating: /content/DataSet/valid/labels/00014_00005_00000_png.rf.1e7b4f22a6f3e4d9fc5b151fddbd41dd.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00008_png.rf.b5591234d317fc4e122c6594039268f9.txt
#   inflating: /content/DataSet/valid/labels/00008_00017_00021_png.rf.e3539348f10ebb2a43c22c2ff8ead631.txt
#   inflating: /content/DataSet/valid/labels/00008_00038_00008_png.rf.2a7a8fd66cf9b684e26801ef89447731.txt
#   inflating: /content/DataSet/valid/labels/00008_00004_00018_png.rf.d04b1e5cf05ad80902d307cc7e6c431d.txt
#   inflating: /content/DataSet/valid/labels/00014_00006_00017_png.rf.009947c10a98db2965b31368471eb4a5.txt
#   inflating: /content/DataSet/valid/labels/00014_00001_00002_png.rf.483438bbdd92061897181234b8964550.txt
#   inflating: /content/DataSet/valid/labels/00008_00024_00015_png.rf.0a488e624b482b0c2c96148cbc582449.txt
#   inflating: /content/DataSet/valid/labels/00008_00008_00020_png.rf.6c66ef0dde590ac7dfddb8a715bd57ac.txt
#   inflating: /content/DataSet/valid/labels/000092_jpg.rf.87588aa3b0f60afb13c9c0a0575693f6.txt
#   inflating: /content/DataSet/valid/labels/00014_00000_00024_png.rf.b6b0de4c0a7b5a38da353cd4fcf3abcb.txt
#   inflating: /content/DataSet/valid/labels/00008_00034_00010_png.rf.c63f6f9720ff1a0ecf10ebfb55844f2d.txt
#   inflating: /content/DataSet/valid/labels/00008_00015_00023_png.rf.d08260bc4588dcab6fe5b54989e91502.txt
#   inflating: /content/DataSet/valid/labels/00014_00001_00000_png.rf.3e50b1a77c9ffef0b94e6a561cc319c8.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00018_png.rf.99f3f18db235a6649470bdf440f30670.txt
#   inflating: /content/DataSet/valid/labels/00008_00039_00022_png.rf.5fa7f0b9ebfa8a702336246e92f63e2c.txt
#   inflating: /content/DataSet/valid/labels/00008_00006_00019_png.rf.9284ba138dea764af54bb1429aeb31ba.txt
#   inflating: /content/DataSet/valid/labels/00008_00044_00020_png.rf.b7f1da92ed0f5a60d3c31f13f4ea524c.txt
#   inflating: /content/DataSet/valid/labels/00008_00012_00026_png.rf.9d73f6bf08134cd2d6f1cee81cc97d44.txt
#   inflating: /content/DataSet/valid/labels/00008_00000_00025_png.rf.54a2c7bed1c4f555a5825fa8b3dd2c7b.txt
#   inflating: /content/DataSet/valid/labels/00008_00013_00010_png.rf.8c734c3859b581451b57c485582f5ce6.txt
#   inflating: /content/DataSet/valid/labels/00008_00008_00019_png.rf.8251d851ef8cfe67c02a3fe47e2b2c43.txt
#   inflating: /content/DataSet/valid/labels/00014_00004_00005_png.rf.7115e64a1cf0236276de71514a635a06.txt
#   inflating: /content/DataSet/valid/labels/00014_00002_00015_png.rf.1d9249429d70efa6eda5490cbb105a1c.txt
#   inflating: /content/DataSet/valid/labels/000098_jpg.rf.4b8be686f943aa7349065e09d710dfa3.txt
#   inflating: /content/DataSet/valid/labels/00008_00007_00012_png.rf.c3d898d938b7deebab53bb896fe22d9b.txt
#   inflating: /content/DataSet/valid/labels/00008_00011_00001_png.rf.552d1ac62d4fbb2d8d76f528f3b8f610.txt
#   inflating: /content/DataSet/valid/labels/000717_jpg.rf.221c34fc5f23b2561f3724382f2bbe87.txt

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

def load_data(data_dir, target_size=(416, 416), num_classes=15):
    images = []
    labels = []

    images_dir = os.path.join(data_dir, 'images')
    labels_dir = os.path.join(data_dir, 'labels')

    for image_file in os.listdir(images_dir):
        if image_file.endswith('.jpg'):
            image_path = os.path.join(images_dir, image_file)
            img = load_img(image_path, target_size=target_size)
            img_array = img_to_array(img) / 255.0
            images.append(img_array)

            label_file = image_file.replace('.jpg', '.txt')
            label_path = os.path.join(labels_dir, label_file)

            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    if lines:
                        first_label = int(lines[0].split()[0])
                        labels.append(first_label)
                    else:
                        print(f"Empty label file for image: {image_file}")
                        labels.append(0)
            else:
                print(f"Label file missing for image: {image_file}")
                labels.append(0)

    images = np.array(images)
    labels = np.array(labels)

    print(f"Images loaded: {len(images)}, Labels loaded: {len(labels)}")
    labels = to_categorical(labels, num_classes=num_classes)

    return images, labels

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical
# Load training, validation, and testing datasets
train_dir = '/content/DataSet/train'
val_dir = '/content/DataSet/valid'
test_dir = '/content/DataSet/test'

X_train, y_train = load_data('/content/DataSet/train', target_size=(416, 416), num_classes=15)
X_val, y_val = load_data('/content/DataSet/valid', target_size=(416, 416), num_classes=15)
X_test, y_test = load_data('/content/DataSet/test', target_size=(416, 416), num_classes=15)
# Check shapes
print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# Empty label file for image: FisheyeCamera_1_00802_png.rf.6a502d781364b74f35bfa71832fc1ede.jpg
# Empty label file for image: FisheyeCamera_1_00807_png.rf.065f778b2eaf15dd7b5beb90b30c490c.jpg
# Empty label file for image: FisheyeCamera_1_00926_png.rf.511cfac04ff48a1fe99b560b4a4fb9e2.jpg
# Images loaded: 3530, Labels loaded: 3530
# Images loaded: 801, Labels loaded: 801
# Empty label file for image: FisheyeCamera_1_00922_png.rf.408835a278b9c700eb1a2f358ca58d07.jpg
# Images loaded: 638, Labels loaded: 638
# (3530, 416, 416, 3) (3530, 15)
# (801, 416, 416, 3) (801, 15)
# (638, 416, 416, 3) (638, 15)

# %%
import os
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import load_img, img_to_array

class DataGenerator(Sequence):
    def __init__(self, data_dir, target_size=(416, 416), num_classes=15, batch_size=32):
        self.images_dir = os.path.join(data_dir, 'images')
        self.labels_dir = os.path.join(data_dir, 'labels')
        self.target_size = target_size
        self.num_classes = num_classes
        self.batch_size = batch_size
        self.image_files = [f for f in os.listdir(self.images_dir) if f.endswith('.jpg')]

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        batch_files = self.image_files[index * self.batch_size:(index + 1) * self.batch_size]
        images = []
        labels = []

        for image_file in batch_files:
            image_path = os.path.join(self.images_dir, image_file)
            img = load_img(image_path, target_size=self.target_size)
            img_array = img_to_array(img) / 255.0
            images.append(img_array)

            label_file = image_file.replace('.jpg', '.txt')
            label_path = os.path.join(self.labels_dir, label_file)
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    if lines:
                        first_label = int(lines[0].split()[0])
                        labels.append(first_label)
                    else:
                        labels.append(0)
            else:
                labels.append(0)
        images = np.array(images)
        labels = np.array(labels)
        labels = np.eye(self.num_classes)[labels]
        return images, labels

# %%
#with corp
import os
import numpy as np
from tensorflow.keras.utils import Sequence
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from PIL import Image

class DataGenerator(Sequence):
    def __init__(self, data_dir, target_size=(416, 416), num_classes=15, batch_size=32):
        self.images_dir = os.path.join(data_dir, 'images')
        self.labels_dir = os.path.join(data_dir, 'labels')
        self.target_size = target_size
        self.num_classes = num_classes
        self.batch_size = batch_size
        self.image_files = [f for f in os.listdir(self.images_dir) if f.endswith('.jpg')]

    def __len__(self):
        return int(np.ceil(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        batch_files = self.image_files[index * self.batch_size:(index + 1) * self.batch_size]
        images = []
        labels = []

        for image_file in batch_files:
            image_path = os.path.join(self.images_dir, image_file)
            img = Image.open(image_path)
            img_width, img_height = img.size

            label_file = image_file.replace('.jpg', '.txt')
            label_path = os.path.join(self.labels_dir, label_file)

            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    for line in lines:
                        class_id, x_center, y_center, width, height = map(float, line.split())

                        x_center *= img_width
                        y_center *= img_height
                        width *= img_width
                        height *= img_height

                        x_min = int(x_center - width / 2)
                        y_min = int(y_center - height / 2)
                        x_max = int(x_center + width / 2)
                        y_max = int(y_center + height / 2)

                        cropped_img = img.crop((x_min, y_min, x_max, y_max))
                        cropped_img = cropped_img.resize(self.target_size)
                        cropped_img_array = img_to_array(cropped_img) / 255.0

                        images.append(cropped_img_array)
                        labels.append(int(class_id))  # Append class ID
            else:
                print(f"Label file missing for {image_file}")

        images = np.array(images)
        labels = np.array(labels)
        labels = np.eye(self.num_classes)[labels]
        return images, labels


    def get_all_labels(self):
        all_labels = []
        for image_file in self.image_files:
            label_file = image_file.replace('.jpg', '.txt')
            label_path = os.path.join(self.labels_dir, label_file)
            if os.path.exists(label_path):
                with open(label_path, 'r') as f:
                    lines = f.readlines()
                    for line in lines:
                        class_id = int(line.split()[0])
                        all_labels.append(class_id)
        return np.array(all_labels)

# %%
# Initialize generators

train_dir = '/content/DataSet/train'
val_dir = '/content/DataSet/valid'
test_dir = '/content/DataSet/test'

batch_size = 32
train_gen = DataGenerator(train_dir, target_size=(416, 416), num_classes=15, batch_size=batch_size)
val_gen = DataGenerator(val_dir, target_size=(416, 416), num_classes=15, batch_size=batch_size)
test_gen = DataGenerator(test_dir, target_size=(416, 416), num_classes=15, batch_size=batch_size)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(416, 416, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(15, activation='softmax')
    ])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_gen, epochs=10, validation_data=val_gen)
# Out:
# Epoch 1/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.2566 - loss: 3.5085 - val_accuracy: 0.4936 - val_loss: 1.5537
# Epoch 2/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 51s 440ms/step - accuracy: 0.4348 - loss: 1.7053 - val_accuracy: 0.6504 - val_loss: 1.2183
# Epoch 3/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 81s 431ms/step - accuracy: 0.5650 - loss: 1.3341 - val_accuracy: 0.7871 - val_loss: 0.8158
# Epoch 4/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 81s 416ms/step - accuracy: 0.6445 - loss: 1.0604 - val_accuracy: 0.7945 - val_loss: 0.6741
# Epoch 5/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 82s 417ms/step - accuracy: 0.6801 - loss: 1.0081 - val_accuracy: 0.8210 - val_loss: 0.5715
# Epoch 6/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 80s 410ms/step - accuracy: 0.7365 - loss: 0.8117 - val_accuracy: 0.8496 - val_loss: 0.5252
# Epoch 7/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 84s 428ms/step - accuracy: 0.7700 - loss: 0.6863 - val_accuracy: 0.8326 - val_loss: 0.5476
# Epoch 8/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 47s 408ms/step - accuracy: 0.7815 - loss: 0.6291 - val_accuracy: 0.8581 - val_loss: 0.4665
# Epoch 9/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 46s 398ms/step - accuracy: 0.8061 - loss: 0.5620 - val_accuracy: 0.8453 - val_loss: 0.5289
# Epoch 10/10
# 111/111 ━━━━━━━━━━━━━━━━━━━━ 49s 420ms/step - accuracy: 0.8116 - loss: 0.5814 - val_accuracy: 0.8496 - val_loss: 0.5479

# %%
model.save('traffic_signs_model.keras')

# %%
test_loss, test_accuracy = model.evaluate(val_gen, verbose=1)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 278ms/step - accuracy: 0.8510 - loss: 0.5830
# Test Accuracy: 84.96%

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Model Accuracy')
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Model Loss')
plt.show()

# %%
# Out:
# /content/DataSet/test/labels

# %%
import numpy as np

predictions = model.predict(test_gen, verbose=1)

predicted_classes = np.argmax(predictions, axis=1)

true_classes = []
for _, labels in test_gen:
    true_classes.extend(np.argmax(labels, axis=1))
    if len(true_classes) >= len(test_gen.image_files):
        break
true_classes = np.array(true_classes[:len(predicted_classes)])

print(f"Predicted: {predicted_classes[:10]}")
print(f"True: {true_classes[:10]}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 17s 831ms/step
# Predicted: [ 5  1  1 11 11 12  4 11 10  0]
# True: [ 6  1  1 11 11 12  4 11 10  0]

# %%
all_test_labels = test_gen.get_all_labels()
print("All test labels:", len(all_test_labels))
# Out:
# All test labels: 770

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Predict the labels on the test data
test_predictions = model.predict(test_gen, verbose=1)

# Convert predictions from probabilities to class labels (use argmax to get the index of the highest probability)
test_predictions = np.argmax(test_predictions, axis=1)

# Generate confusion matrix
cm = confusion_matrix(all_test_labels, test_predictions)

# Plot the confusion matrix using seaborn for better visualization
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=np.unique(all_test_labels), yticklabels=np.unique(all_test_labels))
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 301ms/step

# %%
import matplotlib.pyplot as plt
import random
from PIL import Image

def show_cropped_images(generator, num_samples=5):
    # Retrieve random indices
    random_indices = random.sample(range(len(generator.image_files)), num_samples)

    # Plot cropped images
    plt.figure(figsize=(15, 10))

    for i, idx in enumerate(random_indices):
        # Get the image and label file paths
        image_file = generator.image_files[idx]
        image_path = os.path.join(generator.images_dir, image_file)
        label_file = image_file.replace('.jpg', '.txt')
        label_path = os.path.join(generator.labels_dir, label_file)

        # Load the image
        img = Image.open(image_path)
        img_width, img_height = img.size

        # Load the label and extract bounding boxes
        cropped_images = []
        if os.path.exists(label_path):
            with open(label_path, 'r') as f:
                lines = f.readlines()
                for line in lines:
                    # Parse label information
                    parts = line.split()
                    class_id = int(parts[0])
                    x_center, y_center, width, height = map(float, parts[1:])

                    # Convert normalized coordinates to pixel values
                    x_center *= img_width
                    y_center *= img_height
                    width *= img_width
                    height *= img_height

                    # Get crop box (left, upper, right, lower)
                    left = int(x_center - width / 2)
                    upper = int(y_center - height / 2)
                    right = int(x_center + width / 2)
                    lower = int(y_center + height / 2)

                    # Crop the image
                    cropped_image = img.crop((left, upper, right, lower))
                    cropped_images.append((cropped_image, class_id))

        # Display cropped regions
        for j, (cropped_image, class_id) in enumerate(cropped_images):
            plt.subplot(num_samples, len(cropped_images), i * len(cropped_images) + j + 1)
            plt.imshow(cropped_image)
            plt.axis('off')
            plt.title(f"Class: {class_id}")

    plt.tight_layout()
    plt.show()

# Show 5 random samples with cropped regions
show_cropped_images(test_gen, num_samples=5)
